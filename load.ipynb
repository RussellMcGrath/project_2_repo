# %%
#import dependencies
import pandas as pd
import requests
from sqlalchemy import create_engine
from scrape import clean_data
# Out:
# 1 of 123
# 2 of 123
# 3 of 123
# 4 of 123
# 5 of 123
# 6 of 123
# 7 of 123
# 8 of 123
# 9 of 123
# 10 of 123
# 11 of 123
# 12 of 123
# 13 of 123
# 14 of 123
# 15 of 123
# 16 of 123
# 17 of 123
# 18 of 123
# 19 of 123
# 20 of 123
# 21 of 123
# 22 of 123
# 23 of 123
# 24 of 123
# 25 of 123
# 26 of 123
# 27 of 123
# 28 of 123
# 29 of 123
# 30 of 123
# 31 of 123
# 32 of 123
# 33 of 123
# 34 of 123
# 35 of 123
# 36 of 123
# 37 of 123
# 38 of 123
# 39 of 123
# 40 of 123
# 41 of 123
# 42 of 123
# 43 of 123
# 44 of 123
# 45 of 123
# 46 of 123
# 47 of 123
# 48 of 123
# 49 of 123
# 50 of 123
# 51 of 123
# 52 of 123
# 53 of 123
# 54 of 123
# 55 of 123
# 56 of 123
# 57 of 123
# 58 of 123
# 59 of 123
# 60 of 123
# 61 of 123
# 62 of 123
# 63 of 123
# 64 of 123
# 65 of 123
# 66 of 123
# 67 of 123
# 68 of 123
# 69 of 123
# 70 of 123
# 71 of 123
# 72 of 123
# 73 of 123
# 74 of 123
# 75 of 123
# 76 of 123
# 77 of 123
# 78 of 123
# 79 of 123
# 80 of 123
# 81 of 123
# 82 of 123
# 83 of 123
# 84 of 123
# 85 of 123
# 86 of 123
# 87 of 123
# 88 of 123
# 89 of 123
# 90 of 123
# 91 of 123
# 92 of 123
# 93 of 123
# 94 of 123
# 95 of 123
# 96 of 123
# 97 of 123
# 98 of 123
# 99 of 123
# 100 of 123
# 101 of 123
# 102 of 123
# 103 of 123
# 104 of 123
# 105 of 123
# 106 of 123
# 107 of 123
# 108 of 123
# 109 of 123
# 110 of 123
# 111 of 123
# 112 of 123
# 113 of 123
# 114 of 123
# 115 of 123
# 116 of 123
# 117 of 123
# 118 of 123
# 119 of 123
# 120 of 123
# 121 of 123
# 122 of 123
# 123 of 123
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["cause"] = causes
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["acres"] = sizes

# %%
db_url = "postgres://wjxzypdlczzndp:f8f1e68b9d11167672d5034257f6c8b7516d35b26d8478661a14aa55e165f122@ec2-3-220-23-212.compute-1.amazonaws.com:5432/dav0khodef85hh"

engine = create_engine(db_url)
conn = engine.connect()

# %%
clean_data.to_sql("fires", conn, if_exists="replace")

# %%
engine.execute("ALTER TABLE fires ADD PRIMARY KEY (index)")

# %%
pd.read_sql_query('select * from fires', con=engine).head()
# Out:
#    index                                              title  \
# 0      0  Klamath NF RX Burning 2020/2021 (Prescribed Fire)
# 1      1  Shasta-Trinity RX Burning 2020/2021 (Prescribe...
# 2      2                               Bond Fire (Wildfire)
# 3      3                       Cameron Peak Fire (Wildfire)
# 4      4                         Canyon Wildfire (Wildfire)
#
#                           published              lat               lon  \
# 0  Wed, 09 Dec 2020 16:05:09 -06:00  41.738611111111  -122.77888888889
# 1  Wed, 09 Dec 2020 15:42:45 -06:00  41.371944444444  -121.97138888889
# 2  Tue, 08 Dec 2020 21:03:37 -06:00  33.777222222222  -117.63833333333
# 3  Tue, 08 Dec 2020 12:52:01 -06:00  40.608611111111  -105.87916666667
# 4  Mon, 07 Dec 2020 20:44:22 -06:00  35.881944444444  -118.45805555556
#
#                                  link_url  \
# 0  http://inciweb.nwcg.gov/incident/7274/
# 1  http://inciweb.nwcg.gov/incident/7268/
# 2  http://inciweb.nwcg.gov/incident/7275/
# 3  http://inciweb.nwcg.gov/incident/6964/
# 4  http://inciweb.nwcg.gov/incident/7276/
#
#                                          description       state  \
# 0  After a challenging fire season, the arrival o...  California
# 1   See the 'Announcements' and 'News' Tabs for t...  California
# 2  The Bond Fire started December 2, 2020 at 10:1...  California
# 3  A Type 3 Incident Management Team assumed comm...    Colorado
# 4                                                     California
#
#              cause acres
# 0  Prescribed Fire   n/a
# 1  Prescribed Fire   n/a
# 2  Prescribed Fire   n/a
# 3  Prescribed Fire   n/a
# 4  Prescribed Fire   n/a
