# %%
#import dependencies
import pandas as pd
import requests
from sqlalchemy import create_engine
from scrape import clean_data
# Out:
# 1 of 124
# 2 of 124
# 3 of 124
# 4 of 124
# 5 of 124
# 6 of 124
# 7 of 124
# 8 of 124
# 9 of 124
# 10 of 124
# 11 of 124
# 12 of 124
# 13 of 124
# 14 of 124
# 15 of 124
# 16 of 124
# 17 of 124
# 18 of 124
# 19 of 124
# 20 of 124
# 21 of 124
# 22 of 124
# 23 of 124
# 24 of 124
# 25 of 124
# 26 of 124
# 27 of 124
# 28 of 124
# 29 of 124
# 30 of 124
# 31 of 124
# 32 of 124
# 33 of 124
# 34 of 124
# 35 of 124
# 36 of 124
# 37 of 124
# 38 of 124
# 39 of 124
# 40 of 124
# 41 of 124
# 42 of 124
# 43 of 124
# 44 of 124
# 45 of 124
# 46 of 124
# 47 of 124
# 48 of 124
# 49 of 124
# 50 of 124
# 51 of 124
# 52 of 124
# 53 of 124
# 54 of 124
# 55 of 124
# 56 of 124
# 57 of 124
# 58 of 124
# 59 of 124
# 60 of 124
# 61 of 124
# 62 of 124
# 63 of 124
# 64 of 124
# 65 of 124
# 66 of 124
# 67 of 124
# 68 of 124
# 69 of 124
# 70 of 124
# 71 of 124
# 72 of 124
# 73 of 124
# 74 of 124
# 75 of 124
# 76 of 124
# 77 of 124
# 78 of 124
# 79 of 124
# 80 of 124
# 81 of 124
# 82 of 124
# 83 of 124
# 84 of 124
# 85 of 124
# 86 of 124
# 87 of 124
# 88 of 124
# 89 of 124
# 90 of 124
# 91 of 124
# 92 of 124
# 93 of 124
# 94 of 124
# 95 of 124
# 96 of 124
# 97 of 124
# 98 of 124
# 99 of 124
# 100 of 124
# 101 of 124
# 102 of 124
# 103 of 124
# 104 of 124
# 105 of 124
# 106 of 124
# 107 of 124
# 108 of 124
# 109 of 124
# 110 of 124
# 111 of 124
# 112 of 124
# 113 of 124
# 114 of 124
# 115 of 124
# 116 of 124
# 117 of 124
# 118 of 124
# 119 of 124
# 120 of 124
# 121 of 124
# 122 of 124
# 123 of 124
# 124 of 124
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["cause"] = causes
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["acres"] = sizes

# %%
db_url = "postgres://wjxzypdlczzndp:f8f1e68b9d11167672d5034257f6c8b7516d35b26d8478661a14aa55e165f122@ec2-3-220-23-212.compute-1.amazonaws.com:5432/dav0khodef85hh"

engine = create_engine(db_url)
conn = engine.connect()

# %%
clean_data.to_sql("fires", conn, if_exists="replace")

# %%
engine.execute("ALTER TABLE fires ADD PRIMARY KEY (index)")

# %%
pd.read_sql_query('select * from fires', con=engine).head()
# Out:
#    index                                              title  \
# 0      0                               Bond Fire (Wildfire)
# 1      1                       Cameron Peak Fire (Wildfire)
# 2      2  Klamath NF RX Burning 2020/2021 (Prescribed Fire)
# 3      3                         Canyon Wildfire (Wildfire)
# 4      4                           North Complex (Wildfire)
#
#                           published              lat               lon  \
# 0  Tue, 08 Dec 2020 21:03:37 -06:00  33.777222222222  -117.63833333333
# 1  Tue, 08 Dec 2020 12:52:01 -06:00  40.608611111111  -105.87916666667
# 2  Tue, 08 Dec 2020 12:30:57 -06:00  41.738611111111  -122.77888888889
# 3  Mon, 07 Dec 2020 20:44:22 -06:00  35.881944444444  -118.45805555556
# 4  Mon, 07 Dec 2020 17:50:15 -06:00  40.090833333333  -120.93111111111
#
#                                  link_url  \
# 0  http://inciweb.nwcg.gov/incident/7275/
# 1  http://inciweb.nwcg.gov/incident/6964/
# 2  http://inciweb.nwcg.gov/incident/7274/
# 3  http://inciweb.nwcg.gov/incident/7276/
# 4  http://inciweb.nwcg.gov/incident/6997/
#
#                                          description state    cause   acres
# 0  The Bond Fire started December 2, 2020 at 10:1...        Unknown    6686
# 1  A Type 3 Incident Management Team assumed comm...        Unknown    6686
# 2  After a challenging fire season, the arrival o...        Unknown  208913
# 3                                                           Unknown    6686
# 4   Incident Start Date: 8/17/2020   Size: 318,93...        Unknown  208913
