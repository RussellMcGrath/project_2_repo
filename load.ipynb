# %%
#import dependencies
import pandas as pd
import requests
from sqlalchemy import create_engine
from scrape import clean_data
# Out:
# 1 of 128
# 2 of 128
# 3 of 128
# 4 of 128
# 5 of 128
# 6 of 128
# 7 of 128
# 8 of 128
# 9 of 128
# 10 of 128
# 11 of 128
# 12 of 128
# 13 of 128
# 14 of 128
# 15 of 128
# 16 of 128
# 17 of 128
# 18 of 128
# 19 of 128
# 20 of 128
# 21 of 128
# 22 of 128
# 23 of 128
# 24 of 128
# 25 of 128
# 26 of 128
# 27 of 128
# 28 of 128
# 29 of 128
# 30 of 128
# 31 of 128
# 32 of 128
# 33 of 128
# 34 of 128
# 35 of 128
# 36 of 128
# 37 of 128
# 38 of 128
# 39 of 128
# 40 of 128
# 41 of 128
# 42 of 128
# 43 of 128
# 44 of 128
# 45 of 128
# 46 of 128
# 47 of 128
# 48 of 128
# 49 of 128
# 50 of 128
# 51 of 128
# 52 of 128
# 53 of 128
# 54 of 128
# 55 of 128
# 56 of 128
# 57 of 128
# 58 of 128
# 59 of 128
# 60 of 128
# 61 of 128
# 62 of 128
# 63 of 128
# 64 of 128
# 65 of 128
# 66 of 128
# 67 of 128
# 68 of 128
# 69 of 128
# 70 of 128
# 71 of 128
# 72 of 128
# 73 of 128
# 74 of 128
# 75 of 128
# 76 of 128
# 77 of 128
# 78 of 128
# 79 of 128
# 80 of 128
# 81 of 128
# 82 of 128
# 83 of 128
# 84 of 128
# 85 of 128
# 86 of 128
# 87 of 128
# 88 of 128
# 89 of 128
# 90 of 128
# 91 of 128
# 92 of 128
# 93 of 128
# 94 of 128
# 95 of 128
# 96 of 128
# 97 of 128
# 98 of 128
# 99 of 128
# 100 of 128
# 101 of 128
# 102 of 128
# 103 of 128
# 104 of 128
# 105 of 128
# 106 of 128
# 107 of 128
# 108 of 128
# 109 of 128
# 110 of 128
# 111 of 128
# 112 of 128
# 113 of 128
# 114 of 128
# 115 of 128
# 116 of 128
# 117 of 128
# 118 of 128
# 119 of 128
# 120 of 128
# 121 of 128
# 122 of 128
# 123 of 128
# 124 of 128
# 125 of 128
# 126 of 128
# 127 of 128
# 128 of 128
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["cause"] = causes
# C:\Users\mcgra\Desktop\project_2_repo\scrape.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["acres"] = sizes

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/firedata_db')
conn = engine.connect()

# %%
clean_data.to_sql("fires", conn, if_exists="replace")

# %%
engine.execute("ALTER TABLE fires ADD PRIMARY KEY (index)")

# %%
pd.read_sql_query('select * from fires', con=engine).head()
# Out:
#    index                          title                         published  \
# 0      0           Bond Fire (Wildfire)  Sat, 05 Dec 2020 13:30:09 -06:00
# 1      1   Cameron Peak Fire (Wildfire)  Sat, 05 Dec 2020 10:38:45 -06:00
# 2      2       North Complex (Wildfire)  Fri, 04 Dec 2020 15:36:22 -06:00
# 3      3  Grizzly Creek Fire (Wildfire)  Fri, 04 Dec 2020 09:05:15 -06:00
# 4      4          Creek Fire (Wildfire)  Thu, 03 Dec 2020 18:06:37 -06:00
#
#                lat               lon                                link_url  \
# 0  33.777222222222  -117.63833333333  http://inciweb.nwcg.gov/incident/7275/
# 1  40.608611111111  -105.87916666667  http://inciweb.nwcg.gov/incident/6964/
# 2  40.090833333333  -120.93111111111  http://inciweb.nwcg.gov/incident/6997/
# 3  39.566666666667  -107.27138888889  http://inciweb.nwcg.gov/incident/6942/
# 4  37.201111111111  -119.27166666667  http://inciweb.nwcg.gov/incident/7147/
#
#                                          description    cause   acres
# 0                                                     Unknown    7375
# 1  The Southern Area Gold Type 2 Incident Managem...  Unknown    7375
# 2   The incident command post (ICP) for North Com...  Unknown  208913
# 3  Dec. 4 Update. There has been little activity ...  Unknown    7375
# 4                                                     Unknown  208913
