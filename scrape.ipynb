# %%
#import dependencies

import pandas as pd
from bs4 import BeautifulSoup as bs
#from bs4.element import Comment
#from splinter import Browser
import requests
#import time
#import numpy as np

# %% [markdown]
# ## Extract Data

# %%
#datasource url 
url = "https://inciweb.nwcg.gov/feeds/rss/incidents/"

# %%
# instanciate landing dataframe
starting_data = pd.DataFrame()

# request xml code from url
xml_data = requests.get(url).content

#parse the xml response
soup = bs(xml_data, "xml")
     
# Find all text in the data
texts = str(soup.findAll(text=True)).replace('\\n','')
    
#Find the tag/child
child = soup.find("item")

# instatiate column lists
title = []
published = []
lat = []
lon = []
link = []
description = []

#loop trough each "item" in the xml response and store the target data
while True:    
    try:
        title.append(" ".join(child.find('title')))
    except:
         title.append(" ")
            
    try:
        published.append(" ".join(child.find('published')))
    except:
        published.append(" ")
        
    try:
        lat.append(" ".join(child.find('geo:lat')))
    except:
        lat.append(" ")
            
    try:
        lon.append(" ".join(child.find('geo:long')))
    except:
        lon.append(" ")
        
    try:
        link.append(" ".join(child.find('link')))
    except:
        link.append(" ")
        
    try:
        description.append(" ".join(child.find('description')))
    except:
        description.append(" ")
        
    try:   
        # Next sibling of child, here: 'item' 
        child = child.find_next_sibling('item')
    except:
        break
    
    #create dataframe
    data = pd.DataFrame({"title":title,
                                    "published":published,
                                    "lat":lat,
                                    "lon":lon,
                                    "link_url":link,
                                    "description": description})
    starting_data = starting_data.append(data, ignore_index = True)

# %%
# drop duplicate rows
unique_data = starting_data.drop_duplicates(keep="first",ignore_index="True")
unique_data.head(15)
# Out:
#                                                 title  \
# 0                               Creek Fire (Wildfire)
# 1                           Riverside Fire (Wildfire)
# 2                               Dolan Fire (Wildfire)
# 3   Klamath NF RX Burning 2020/2021 (Prescribed Fire)
# 4                         Rattlesnake Fire (Wildfire)
# 5                        Cameron Peak Fire (Wildfire)
# 6   2020-21 Royal Gorge FO Pile Burns (Prescribed ...
# 7   Shasta-Trinity RX Burning 2020/2021 (Prescribe...
# 8      Woodhead BAER (Burned Area Emergency Response)
# 9                          Big Hollow Fire (Wildfire)
# 10  East Troublesome Post-Fire BAER (Burned Area E...
# 11                   East Troublesome Fire (Wildfire)
# 12                      Williams Fork Fire (Wildfire)
# 13                             SQF Complex (Wildfire)
# 14  Fall Prescribed Fire Projects 2020 (Prescribed...
#
#                            published              lat               lon  \
# 0   Thu, 03 Dec 2020 18:06:37 -06:00  37.201111111111  -119.27166666667
# 1   Thu, 03 Dec 2020 17:48:24 -06:00  45.049166666667  -122.06222222222
# 2   Thu, 03 Dec 2020 15:40:38 -06:00  36.123333333333  -121.60166666667
# 3   Thu, 03 Dec 2020 15:09:37 -06:00  41.738611111111  -122.77888888889
# 4   Thu, 03 Dec 2020 13:31:38 -06:00  36.419722222222  -118.44833333333
# 5   Thu, 03 Dec 2020 13:00:37 -06:00  40.608611111111  -105.87916666667
# 6   Thu, 03 Dec 2020 10:39:27 -06:00  38.444722222222  -105.19638888889
# 7   Wed, 02 Dec 2020 09:33:20 -06:00  41.371944444444  -121.97138888889
# 8   Tue, 01 Dec 2020 17:51:59 -06:00  44.756111111111  -116.87666666667
# 9   Tue, 01 Dec 2020 13:44:54 -06:00  45.926944444444           -121.98
# 10  Tue, 01 Dec 2020 10:45:30 -06:00            40.25            -105.9
# 11  Tue, 01 Dec 2020 10:43:57 -06:00  40.200555555556  -106.23416666667
# 12  Tue, 01 Dec 2020 10:37:42 -06:00  39.851111111111  -106.06472222222
# 13  Tue, 01 Dec 2020 07:35:02 -06:00           36.255  -118.49666666667
# 14  Mon, 30 Nov 2020 14:20:28 -06:00  44.417777777778  -118.95138888889
#
#                                   link_url  \
# 0   http://inciweb.nwcg.gov/incident/7147/
# 1   http://inciweb.nwcg.gov/incident/7174/
# 2   http://inciweb.nwcg.gov/incident/7018/
# 3   http://inciweb.nwcg.gov/incident/7274/
# 4   http://inciweb.nwcg.gov/incident/7131/
# 5   http://inciweb.nwcg.gov/incident/6964/
# 6   http://inciweb.nwcg.gov/incident/7266/
# 7   http://inciweb.nwcg.gov/incident/7268/
# 8   http://inciweb.nwcg.gov/incident/7262/
# 9   http://inciweb.nwcg.gov/incident/7171/
# 10  http://inciweb.nwcg.gov/incident/7267/
# 11  http://inciweb.nwcg.gov/incident/7242/
# 12  http://inciweb.nwcg.gov/incident/6971/
# 13  http://inciweb.nwcg.gov/incident/7048/
# 14  http://inciweb.nwcg.gov/incident/7216/
#
#                                           description
# 0
# 1   The Riverside Fire started September 8, 2020 a...
# 2    The Dolan Fire will be considered contained/c...
# 3   After a challenging fire season, the arrival o...
# 4   The Rattlesnake Fire was discovered on August ...
# 5   The Southern Area Gold Type 2 Incident Managem...
# 6   November 12, 2020Bureau of Land Management pla...
# 7    See the 'Announcements' and 'News' Tabs for t...
# 8     The Woodhead Fire burned almost 100,000 acre...
# 9    The Big Hollow Fire is now considered to be 7...
# 10  THREE PHASES OF WILDFIRE RECOVERYThere are thr...
# 11  The East Troublesome Fire was reported on the ...
# 12  The Williams Fork Fire was first reported on A...
# 13  Operations Map |  Fire History Map |   Land Ow...
# 14   Please take a moment to look at the links sec...

# %%
# go the the link url for each rown and extract additional data (cause, size)

#instatiate landing lists
causes = []
sizes = []

#loop through each row of data
for x in range(len(unique_data)):
    #find the link in the row
    url = starting_data.loc[x,"link_url"]
    #go to the page and grap all the tables
    tables = pd.read_html(url)
    
    #the number of tables the page has will determine which tables we look in for data.
    #if there are more than one tables...
    if len(tables)>1:
        try:
            # find the "cause" in the first table on the page (if it exists)
            cause = tables[0].iloc[2,1]
        except:
            cause = "unknown"
    
        try:
            # find the "size" in the second table on the page (if it exists)
            size = tables[1].loc[(tables[1][0]) == "Size",1].item()            
        except:
            size = "unknown"
    #if there is only one table on the page...
    else:
        try:
            # find the "cause" in the first table on the page (if it exists)
            cause = tables[0].iloc[1,1]
            # no size data is available
            size = "n/a"
        except:
            cause = "unknown"
    
    #add cause and size to their lists
    causes.append(cause)
    sizes.append(size)
    
    #print progress
    print(f"{x+1} of {len(unique_data)}")
# Out:
# 1 of 130
# 2 of 130
# 3 of 130
# 4 of 130
# 5 of 130
# 6 of 130
# 7 of 130
# 8 of 130
# 9 of 130
# 10 of 130
# 11 of 130
# 12 of 130
# 13 of 130
# 14 of 130
# 15 of 130
# 16 of 130
# 17 of 130
# 18 of 130
# 19 of 130
# 20 of 130
# 21 of 130
# 22 of 130
# 23 of 130
# 24 of 130
# 25 of 130
# 26 of 130
# 27 of 130
# 28 of 130
# 29 of 130
# 30 of 130
# 31 of 130
# 32 of 130
# 33 of 130
# 34 of 130
# 35 of 130
# 36 of 130
# 37 of 130
# 38 of 130
# 39 of 130
# 40 of 130
# 41 of 130
# 42 of 130
# 43 of 130
# 44 of 130
# 45 of 130
# 46 of 130
# 47 of 130
# 48 of 130
# 49 of 130
# 50 of 130
# 51 of 130
# 52 of 130
# 53 of 130
# 54 of 130
# 55 of 130
# 56 of 130
# 57 of 130
# 58 of 130
# 59 of 130
# 60 of 130
# 61 of 130
# 62 of 130
# 63 of 130
# 64 of 130
# 65 of 130
# 66 of 130
# 67 of 130
# 68 of 130
# 69 of 130
# 70 of 130
# 71 of 130
# 72 of 130
# 73 of 130
# 74 of 130
# 75 of 130
# 76 of 130
# 77 of 130
# 78 of 130
# 79 of 130
# 80 of 130
# 81 of 130
# 82 of 130
# 83 of 130
# 84 of 130
# 85 of 130
# 86 of 130
# 87 of 130
# 88 of 130
# 89 of 130
# 90 of 130
# 91 of 130
# 92 of 130
# 93 of 130
# 94 of 130
# 95 of 130
# 96 of 130
# 97 of 130
# 98 of 130
# 99 of 130
# 100 of 130
# 101 of 130
# 102 of 130
# 103 of 130
# 104 of 130
# 105 of 130
# 106 of 130
# 107 of 130
# 108 of 130
# 109 of 130
# 110 of 130
# 111 of 130
# 112 of 130
# 113 of 130
# 114 of 130
# 115 of 130
# 116 of 130
# 117 of 130
# 118 of 130
# 119 of 130
# 120 of 130
# 121 of 130
# 122 of 130
# 123 of 130
# 124 of 130
# 125 of 130
# 126 of 130
# 127 of 130
# 128 of 130
# 129 of 130
# 130 of 130

# %% [markdown]
# ## Clean/Transform Data

# %%
# if cause has the word "investigation" in it, set cause to "unknown"
for y in range(len(causes)):
    if "Investigation" in causes[y]:
        causes[y] = "Unknown"

# remove the word "Acres" from the size data
sizes = [s.replace(" Acres","") for s in sizes]
sizes = [s.replace(",","") for s in sizes]

# %%
# add causes and sizes to the dataframe
unique_data["cause"] = causes
unique_data["acres"] = sizes
# Out:
# <ipython-input-7-9acd8c5b95cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["cause"] = causes
# <ipython-input-7-9acd8c5b95cc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_data["acres"] = sizes

# %%
# see the counts of each fire cause for reference
grouped_df = unique_data.groupby(["cause"])
grouped_df.count()
# Out:
#                                 title  published  lat  lon  link_url  \
# cause
# Burned Area Emergency Response     13         13   13   13        13
# Human                              15         15   15   15        15
# Lightning                          14         14   14   14        14
# Prescribed Fire                    33         33   33   33        33
# Unknown                            55         55   55   55        55
#
#                                 description  acres
# cause
# Burned Area Emergency Response           13     13
# Human                                    15     15
# Lightning                                14     14
# Prescribed Fire                          33     33
# Unknown                                  55     55

# %%
# save the dataframe as "clean_data"

clean_data = unique_data
clean_data.head()
# Out:
#                                                title  \
# 0                              Creek Fire (Wildfire)
# 1                          Riverside Fire (Wildfire)
# 2                              Dolan Fire (Wildfire)
# 3  Klamath NF RX Burning 2020/2021 (Prescribed Fire)
# 4                        Rattlesnake Fire (Wildfire)
#
#                           published              lat               lon  \
# 0  Thu, 03 Dec 2020 18:06:37 -06:00  37.201111111111  -119.27166666667
# 1  Thu, 03 Dec 2020 17:48:24 -06:00  45.049166666667  -122.06222222222
# 2  Thu, 03 Dec 2020 15:40:38 -06:00  36.123333333333  -121.60166666667
# 3  Thu, 03 Dec 2020 15:09:37 -06:00  41.738611111111  -122.77888888889
# 4  Thu, 03 Dec 2020 13:31:38 -06:00  36.419722222222  -118.44833333333
#
#                                  link_url  \
# 0  http://inciweb.nwcg.gov/incident/7147/
# 1  http://inciweb.nwcg.gov/incident/7174/
# 2  http://inciweb.nwcg.gov/incident/7018/
# 3  http://inciweb.nwcg.gov/incident/7274/
# 4  http://inciweb.nwcg.gov/incident/7131/
#
#                                          description    cause   acres
# 0                                                     Unknown  379895
# 1  The Riverside Fire started September 8, 2020 a...  Unknown  379895
# 2   The Dolan Fire will be considered contained/c...    Human  138054
# 3  After a challenging fire season, the arrival o...  Unknown  379895
# 4  The Rattlesnake Fire was discovered on August ...    Human  138054

# %%
#store as csv for testing
clean_data.to_csv("csv/data.csv")
